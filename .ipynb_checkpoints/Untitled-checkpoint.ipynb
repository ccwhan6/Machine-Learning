# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t1 = np.random.randn(500,2)
t2 = np.random.randn(500,2)
t3 = np.random.randn(500,2)
t4 = np.random.randn(500,2)
std = 3

t1 = std * t1 + 7
t2 = std * t2 + 17
t3 = std * t3 + 7
t4 = std * t4 + 17

trainData = np.zeros((1000,3))
testData = np.zeros((1000,3))

for num in range(1000):
    if num < 500:
        trainData[num,0] = t1[num,0]
        trainData[num,1] = t1[num,1]
        trainData[num,2] = 1
    else :
        trainData[num,0] = t2[num-500,0]
        trainData[num,1] = t2[num-500,1]
        
for num in range(1000):
    if num < 500:
        testData[num,0] = t3[num,0]
        testData[num,1] = t3[num,1]
        testData[num,2] = 1
    else :
        testData[num,0] = t4[num-500,0]
        testData[num,1] = t4[num-500,1]

# %%
to = trainData[:500, :2]
tz = trainData[500:, :2]

plt.title("Training Dataset")
plt.scatter(to[:, 0], to[:, 1], s=10)
plt.scatter(tz[:, 0], tz[:, 1], s=10)
plt.show

to = testData[:500, :2]
tz = testData[500:, :2]

plt.figure()
plt.title("Testing Dataset")
plt.scatter(to[:, 0], to[:, 1], s=10)
plt.scatter(tz[:, 0], tz[:, 1], s=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def crossEntropy(l,y):
    return -(y * np.log(l) + ((1 - y) * np.log(1 - l)))       

def loss(l,y):
    return (1 / 1000) * np.sum(crossEntropy(l,y))

def du(z):
    return (1 / 1000) * np.sum((sigmoid(z) - trainData[:,2]) * trainData[: ,0])

def dv(z):
    return (1 / 1000) * np.sum((sigmoid(z) - trainData[:,2]) * trainData[: ,1])

def db(z):
    return (1 / 1000) * np.sum((sigmoid(z) - trainData[:,2]))

def accuracy(l,y):
    cor = 0
    for num in range(1000):
        if (y > 0.5 and l == 1):
            cor = cor + 1
        elif (y <= 0.5 and l == 0):
            cor = cor + 1
    return cor / 1000

# %%
learningRate = 0.015
w = np.array([0,0])
b = 0
trainLoss = []
testLoss = []
trainAcc = []
testAcc = []

while True:
    trainZ = np.dot(w.T,trainData[:, :2]) + b
    testZ = np.dot(w.T,trainData[:, :2]) + b
    
    w[0] = w[0] - (learningRate * du(trainZ))
    w[1] = w[1] - (learningRate * dv(trainZ))
    b = b - (learningRate * db(trainZ))
    
    trainLoss.append(loss(trainData[:, 2]),sigmoid(trainZ))
# Out:
# [[ 9.16341066  5.63627157]
#  [ 6.16238533  5.83445228]
#  [ 3.75154533  5.01952978]
#  ...
#  [13.78163062 15.34904314]
#  [15.35507378 14.59447833]
#  [21.94151951 19.65833534]]
